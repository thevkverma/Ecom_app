# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_excel('ecom_sales_data.xlsx')
data
# Out:
#      User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0    1000001  P00069042      F   0-17          10             A
# 1    1000001  P00248942      F   0-17          10             A
# 2    1000001  P00087842      F   0-17          10             A
# 3    1000001  P00085442      F   0-17          10             A
# 4    1000002  P00285442      M    55+          16             C
# ..       ...        ...    ...    ...         ...           ...
# 267  1000048  P00147742      M  26-35           4             B
# 268  1000048  P00303742      M  26-35           4             B
# 269  1000048  P00223242      M  26-35           4             B
# 270  1000048  P00114942      M  26-35           4             B
# 271  1000048  P00277442      M  26-35           4             B
#
#     Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                            2               0                 3      8370
# 1                            2               0                 1     15200
# 2                            2               0                12      1422
# 3                            2               0                12      1057
# 4                           4+               0                 8      7969
# ..                         ...             ...               ...       ...
# 267                          3               1                 1     11420
# 268                          3               1                 8      5897
# 269                          3               1                 5      7048
# 270                          3               1                 1     15783
# 271                          3               1                 1     11396
#
# [272 rows x 10 columns]

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                          2               0                 3      8370
# 1                          2               0                 1     15200
# 2                          2               0                12      1422
# 3                          2               0                12      1057
# 4                         4+               0                 8      7969

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category',
#        'Purchase'],
#       dtype='object')

# %%
data.describe()
# Out:
#             User_ID  Occupation  Marital_Status  Product_Category  \
# count  2.720000e+02  272.000000      272.000000        272.000000
# mean   1.000026e+06    6.849265        0.518382          4.963235
# std    1.281626e+01    5.839432        0.500583          3.509414
# min    1.000001e+06    0.000000        0.000000          1.000000
# 25%    1.000017e+06    3.000000        0.000000          1.000000
# 50%    1.000026e+06    5.500000        1.000000          5.000000
# 75%    1.000036e+06   10.000000        1.000000          8.000000
# max    1.000048e+06   20.000000        1.000000         16.000000
#
#            Purchase
# count    272.000000
# mean    9186.628676
# std     5026.241883
# min      584.000000
# 25%     5410.000000
# 50%     7879.500000
# 75%    12196.250000
# max    20961.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     272 non-null    int64
#  1   Product_ID                  272 non-null    object
#  2   Gender                      272 non-null    object
#  3   Age                         272 non-null    object
#  4   Occupation                  272 non-null    int64
#  5   City_Category               272 non-null    object
#  6   Stay_In_Current_City_Years  272 non-null    object
#  7   Marital_Status              272 non-null    int64
#  8   Product_Category            272 non-null    int64
#  9   Purchase                    272 non-null    int64
# dtypes: int64(5), object(5)
# memory usage: 21.4+ KB

# %%
data[["User_ID", "Product_ID","Marital_Status"]]
# Out:
#      User_ID Product_ID  Marital_Status
# 0    1000001  P00069042               0
# 1    1000001  P00248942               0
# 2    1000001  P00087842               0
# 3    1000001  P00085442               0
# 4    1000002  P00285442               0
# ..       ...        ...             ...
# 267  1000048  P00147742               1
# 268  1000048  P00303742               1
# 269  1000048  P00223242               1
# 270  1000048  P00114942               1
# 271  1000048  P00277442               1
#
# [272 rows x 3 columns]

# %%
import seaborn as sns

# %%
sns.countplot(data, x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data, x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(data, x='Age', hue='Marital_Status')
# Out:
# <Axes: xlabel='Age', ylabel='count'>
